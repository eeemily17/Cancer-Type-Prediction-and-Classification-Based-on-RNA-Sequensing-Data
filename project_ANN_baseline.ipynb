# %%
# load the raw dataset
import numpy as np
import pandas as pd
from pandas import DataFrame

rawdf = pd.read_csv("unc.edu_PANCAN_IlluminaHiSeq_RNASeqV2.geneExp.tsv", sep="\t", index_col=0)
rawdf.head()
# Out:
#              TCGA-OR-A5J1-01A-11R-A29S-07  TCGA-OR-A5J2-01A-11R-A29S-07  \
# 0.0gene_id
# ?|100130426                        0.0000                        0.0000
# ?|100133144                        3.2661                        2.6815
# ?|100134869                        3.9385                        8.9948
# ?|10357                          149.1350                       81.0777
# ?|10431                         2034.1000                     1304.9300
#
#              TCGA-OR-A5J3-01A-11R-A29S-07  TCGA-OR-A5J5-01A-11R-A29S-07  \
# 0.0gene_id
# ?|100130426                        0.0000                        0.0000
# ?|100133144                        1.7301                        0.0000
# ?|100134869                        6.5650                        1.5492
# ?|10357                           86.4879                       53.9117
# ?|10431                         1054.6600                     2350.8900
#
#              TCGA-OR-A5J6-01A-31R-A29S-07  TCGA-OR-A5J7-01A-11R-A29S-07  \
# 0.0gene_id
# ?|100130426                        0.0000                        0.0000
# ?|100133144                        0.0000                        1.1673
# ?|100134869                        4.4709                        6.0529
# ?|10357                           66.9063                      103.5060
# ?|10431                         1257.9900                     1866.4300
#
#              TCGA-OR-A5J8-01A-11R-A29S-07  TCGA-OR-A5J9-01A-11R-A29S-07  \
# 0.0gene_id
# ?|100130426                        0.0000                        0.0000
# ?|100133144                        1.4422                        0.0000
# ?|100134869                        2.2876                        1.3599
# ?|10357                           94.9316                       78.1955
# ?|10431                          995.0270                     1762.1200
#
#              TCGA-OR-A5JA-01A-11R-A29S-07  TCGA-OR-A5JB-01A-11R-A29S-07  \
# 0.0gene_id
# ?|100130426                        0.0000                        0.0000
# ?|100133144                        4.4556                        7.1293
# ?|100134869                        5.0581                        0.0000
# ?|10357                           69.2389                      155.7090
# ?|10431                         1213.5300                     2005.5700
#
#                          ...               TCGA-VQ-AA6A-01A-11R-A414-31  \
# 0.0gene_id               ...
# ?|100130426              ...                                     0.0000
# ?|100133144              ...                                    26.1744
# ?|100134869              ...                                    14.3662
# ?|10357                  ...                                    11.5541
# ?|10431                  ...                                   357.7860
#
#              TCGA-VQ-AA6B-01A-11R-A414-31  TCGA-VQ-AA6D-01A-11R-A414-31  \
# 0.0gene_id
# ?|100130426                        0.3189                        0.0000
# ?|100133144                       28.1937                       32.4153
# ?|100134869                       16.5156                       21.5482
# ?|10357                           10.0447                       15.9546
# ?|10431                          780.6260                      903.2380
#
#              TCGA-VQ-AA6F-01A-31R-A414-31  TCGA-VQ-AA6G-01A-11R-A414-31  \
# 0.0gene_id
# ?|100130426                        0.0000                        0.0000
# ?|100133144                       18.6091                       33.7625
# ?|100134869                       17.2753                       20.2653
# ?|10357                           21.9117                        8.4115
# ?|10431                         1033.0300                      733.7430
#
#              TCGA-VQ-AA6I-01A-11R-A414-31  TCGA-VQ-AA6J-01A-11R-A414-31  \
# 0.0gene_id
# ?|100130426                        0.0000                        0.2466
# ?|100133144                       35.0189                       27.6770
# ?|100134869                       30.1605                       19.2494
# ?|10357                           21.6463                       35.6665
# ?|10431                          519.9930                      709.6430
#
#              TCGA-VQ-AA6K-01A-11R-A414-31  TCGA-ZA-A8F6-01A-23R-A36D-31  \
# 0.0gene_id
# ?|100130426                        0.4134                        0.0000
# ?|100133144                       28.6855                       29.3939
# ?|100134869                       21.1378                       15.4703
# ?|10357                           11.5371                       22.0386
# ?|10431                          702.4730                      561.9840
#
#              TCGA-ZQ-A9CR-01A-11R-A39E-31
# 0.0gene_id
# ?|100130426                        0.5668
# ?|100133144                       19.8016
# ?|100134869                        8.5379
# ?|10357                           29.3701
# ?|10431                         1874.0200
#
# [5 rows x 10471 columns]

# %%
# transpose raw dataset so row is patient samples and column is list of genes
processeddf = rawdf.transpose()
# load class label
dflabels = pd.read_csv('project_class_labels_original_10471.csv',index_col='Unnamed: 0')

# %%
# check to see if there is any feature (i.e. column) has all zero values so we will delete them
removedAllZeroColdf = processeddf.loc[:, (processeddf != 0).any(axis=0)]
removedAllZeroColdf.shape
# Out:
# (10471, 20319)

# %%
# data scaling
# method 1 : standardization
from sklearn.preprocessing import StandardScaler

stdscaler = StandardScaler()
stdscalerfit = stdscaler.fit_transform(removedAllZeroColdf)

stddf = DataFrame(stdscalerfit,index = removedAllZeroColdf.index, columns = removedAllZeroColdf.columns)
stddf.head()
# Out:
# 0.0gene_id                    ?|100130426  ?|100133144  ?|100134869   ?|10357  \
# TCGA-OR-A5J1-01A-11R-A29S-07    -0.160942    -0.617169    -0.576054  0.381991
# TCGA-OR-A5J2-01A-11R-A29S-07    -0.160942    -0.660038    -0.245485 -0.530733
# TCGA-OR-A5J3-01A-11R-A29S-07    -0.160942    -0.729806    -0.404340 -0.458176
# TCGA-OR-A5J5-01A-11R-A29S-07    -0.160942    -0.856677    -0.732261 -0.895059
# TCGA-OR-A5J6-01A-31R-A29S-07    -0.160942    -0.856677    -0.541247 -0.720787
#
# 0.0gene_id                     ?|10431  ?|136542  ?|155060   ?|26823  \
# TCGA-OR-A5J1-01A-11R-A29S-07  2.670834 -0.031973  0.157343  0.840137
# TCGA-OR-A5J2-01A-11R-A29S-07  0.869174 -0.031973 -0.178775 -0.612835
# TCGA-OR-A5J3-01A-11R-A29S-07  0.250798 -0.031973  0.489805 -0.015371
# TCGA-OR-A5J5-01A-11R-A29S-07  3.453570 -0.031973  0.896991  0.168255
# TCGA-OR-A5J6-01A-31R-A29S-07  0.753193 -0.031973 -0.403383 -0.612835
#
# 0.0gene_id                    ?|280660  ?|317712     ...       ZXDA|7789  \
# TCGA-OR-A5J1-01A-11R-A29S-07 -0.110518 -0.018862     ...       -1.119447
# TCGA-OR-A5J2-01A-11R-A29S-07 -0.110518 -0.018862     ...        0.030730
# TCGA-OR-A5J3-01A-11R-A29S-07 -0.110518 -0.018862     ...       -0.519653
# TCGA-OR-A5J5-01A-11R-A29S-07 -0.110518 -0.018862     ...       -1.208814
# TCGA-OR-A5J6-01A-31R-A29S-07 -0.110518 -0.018862     ...       -1.365085
#
# 0.0gene_id                    ZXDB|158586  ZXDC|79364  ZYG11A|440590  \
# TCGA-OR-A5J1-01A-11R-A29S-07    -0.275935   -0.226144      -0.323150
# TCGA-OR-A5J2-01A-11R-A29S-07    -0.592270    3.777421      -0.148785
# TCGA-OR-A5J3-01A-11R-A29S-07     0.350741   -0.508585      -0.322517
# TCGA-OR-A5J5-01A-11R-A29S-07    -0.910432   -0.558491      -0.260347
# TCGA-OR-A5J6-01A-31R-A29S-07    -1.294606   -0.550297      -0.281743
#
# 0.0gene_id                    ZYG11B|79699  ZYX|7791  ZZEF1|23140  ZZZ3|26009  \
# TCGA-OR-A5J1-01A-11R-A29S-07     -0.613014 -0.890816    -0.239301   -0.498587
# TCGA-OR-A5J2-01A-11R-A29S-07      0.441277 -0.537709     0.802185    0.105872
# TCGA-OR-A5J3-01A-11R-A29S-07     -0.291222 -0.654849     0.218941   -0.965491
# TCGA-OR-A5J5-01A-11R-A29S-07     -0.805662 -0.738183    -0.263757   -0.743461
# TCGA-OR-A5J6-01A-31R-A29S-07     -0.312786 -1.219005    -0.748683   -0.852823
#
# 0.0gene_id                    psiTPTE22|387590  tAKR|389932
# TCGA-OR-A5J1-01A-11R-A29S-07          1.137707    -0.120793
# TCGA-OR-A5J2-01A-11R-A29S-07          0.858771    -0.139824
# TCGA-OR-A5J3-01A-11R-A29S-07         -0.089382    -0.153554
# TCGA-OR-A5J5-01A-11R-A29S-07          1.428387    -0.153554
# TCGA-OR-A5J6-01A-31R-A29S-07          0.247311    -0.153554
#
# [5 rows x 20319 columns]

# %%
# split 80% training set; 20% testing set
from sklearn.model_selection import train_test_split

trainData, testData, trainLabel, testLabel = train_test_split(stddf, dflabels, test_size=0.20)

# %%
# ANN
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# measure training time
import time

mlp = MLPClassifier(activation='relu', alpha=0.0001,
       hidden_layer_sizes=(850,800), learning_rate='constant',
       max_iter=200, random_state=0, solver='adam')

start = time.time()
mlp.fit(trainData, trainLabel.values.ravel())
end = time.time()
print("ANN training time: ", end - start)

pred = mlp.predict(testData)
accuracy = accuracy_score(testLabel, pred)
print("Accuracy Score (ANN):", accuracy)

# confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(testLabel, pred)
print(confusion_matrix)
# classficiation report
from sklearn.metrics import classification_report
print(classification_report(testLabel, pred))
# Out:
# ANN training time:  1123.3117859363556
# Accuracy Score (ANN): 0.947971360382
# [[ 21   0   0 ...,   0   0   0]
#  [  0  83   0 ...,   0   1   0]
#  [  0   1 221 ...,   0   0   0]
#  ...,
#  [  0   0   0 ...,  38   2   0]
#  [  0   0   0 ...,   2   7   0]
#  [  0   0   0 ...,   0   0  13]]
#              precision    recall  f1-score   support
#
#         ACC       1.00      0.95      0.98        22
#        BLCA       0.91      0.92      0.92        90
#        BRCA       0.98      0.99      0.98       223
#        CESC       0.89      0.82      0.85        50
#        CHOL       1.00      0.25      0.40         8
#        COAD       0.87      0.84      0.85        55
#        DLBC       1.00      1.00      1.00        10
#        ESCA       0.82      0.94      0.88        35
#         GBM       0.71      0.94      0.81        36
#        HNSC       0.98      0.97      0.97       126
#        KICH       0.81      0.76      0.79        17
#        KIRC       0.99      0.97      0.98       113
#        KIRP       0.93      0.93      0.93        61
#        LAML       1.00      1.00      1.00        34
#         LGG       0.99      0.89      0.94       122
#        LIHC       0.95      1.00      0.98        82
#        LUAD       0.93      0.94      0.93       113
#        LUSC       0.95      0.94      0.95       133
#        MESO       0.94      1.00      0.97        17
#          OV       1.00      0.99      0.99        68
#        PAAD       0.97      1.00      0.98        32
#        PCPG       1.00      1.00      1.00        43
#        PRAD       1.00      1.00      1.00       115
#        READ       0.44      0.53      0.48        15
#        SARC       0.91      0.92      0.91        64
#        SKCM       0.95      0.97      0.96        79
#        STAD       0.98      0.93      0.95        87
#        TGCT       1.00      1.00      1.00        41
#        THCA       1.00      1.00      1.00       114
#        THYM       1.00      1.00      1.00        26
#        UCEC       0.86      0.90      0.88        42
#         UCS       0.70      0.78      0.74         9
#         UVM       1.00      1.00      1.00        13
#
# avg / total       0.95      0.95      0.95      2095
